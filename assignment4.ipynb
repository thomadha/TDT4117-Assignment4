# %% [markdown]
# # Assignment 4
#
# ## Task 1:
#
# ### Inverted list:

# %%
from collections import defaultdict
import re

# Sample text
text = "Ocean environment is a deep and complex ecosystem filled with diverse creatures. Yet, much about the ocean lacks exploration."

# Define stop words. Based on the text, we chose some common stop words.
stop_words = {"is", "a", "and", "with", "the", "about", "yet"}

# Step 1: Tokenize text and filter out stop words
words = [word.lower() for word in re.findall(r'\w+', text) if word.lower() not in stop_words]

print(" (a): Text after removing stop-words:")
print(words)

# Step 2: Set block size for block addressing
# We chose a block size of 2 for this example. The block size is arbitrary and depends on balancing precision and storage efficiency.
# Since this is a fairly small text, we chose a smaller block size of 2, which provides higher precision in locating terms and doesn't affect storage efficiency.
block_size = 2

# Step 3a: Build the original inverted index with individual positions
inverted_index_positions = defaultdict(list)
for pos, word in enumerate(words):
    inverted_index_positions[word].append(pos)

# Step 3b: Build the inverted index with block addressing
inverted_index_block = defaultdict(set)
for pos, word in enumerate(words):
    # Calculate the block number for each position
    block_num = pos // block_size
    inverted_index_block[word].add(block_num)

# Convert sets to lists for final output format
inverted_index_block = {word: sorted(list(blocks)) for word, blocks in inverted_index_block.items()}

# Display both inverted indexes
print("\nInverted index with individual positions")
print(dict(inverted_index_positions))  # Convert defaultdict to dict for clean display

print("\n (b): Inverted index with block addressing")
print(inverted_index_block)
# Out:
#  (a): Text after removing stop-words:
# ['ocean', 'environment', 'deep', 'complex', 'ecosystem', 'filled', 'diverse', 'creatures', 'much', 'ocean', 'lacks', 'exploration']
#
# Inverted index with individual positions
# {'ocean': [0, 9], 'environment': [1], 'deep': [2], 'complex': [3], 'ecosystem': [4], 'filled': [5], 'diverse': [6], 'creatures': [7], 'much': [8], 'lacks': [10], 'exploration': [11]}
#
#  (b): Inverted index with block addressing
# {'ocean': [0, 4], 'environment': [0], 'deep': [1], 'complex': [1], 'ecosystem': [2], 'filled': [2], 'diverse': [3], 'creatures': [3], 'much': [4], 'lacks': [5], 'exploration': [5]}

# %% [markdown]
#  (c): Partial vocabulary suffix tree

# %%
class SuffixTreeNode:
    def __init__(self):
        self.children = {}
        self.is_end_of_suffix = False

class SuffixTree:
    def __init__(self):
        self.root = SuffixTreeNode()

    def insert_suffix(self, suffix):
        node = self.root
        for char in suffix:
            if char not in node.children:
                node.children[char] = SuffixTreeNode()
            node = node.children[char]
        node.is_end_of_suffix = True

    def build_suffix_tree(self, word):
        for i in range(len(word)):
            self.insert_suffix(word[i:])

    def display_tree(self, node=None, prefix=''):
        if node is None:
            node = self.root
        for char, child in node.children.items():
            print(prefix + char)
            self.display_tree(child, prefix + char)

# Example usage
suffix_tree = SuffixTree()
suffix_tree.build_suffix_tree("ocean")
suffix_tree.build_suffix_tree("environment")
suffix_tree.build_suffix_tree("explore")

print("Partial Suffix Tree:")
suffix_tree.display_tree()
# Out:
# Partial Suffix Tree:
# o
# oc
# oce
# ocea
# ocean
# on
# onm
# onme
# onmen
# onment
# or
# ore
# c
# ce
# cea
# cean
# e
# ea
# ean
# en
# env
# envi
# envir
# enviro
# environ
# environm
# environme
# environmen
# environment
# ent
# ex
# exp
# expl
# explo
# explor
# explore
# a
# an
# n
# nv
# nvi
# nvir
# nviro
# nviron
# nvironm
# nvironme
# nvironmen
# nvironment
# nm
# nme
# nmen
# nment
# nt
# v
# vi
# vir
# viro
# viron
# vironm
# vironme
# vironmen
# vironment
# i
# ir
# iro
# iron
# ironm
# ironme
# ironmen
# ironment
# r
# ro
# ron
# ronm
# ronme
# ronmen
# ronment
# re
# m
# me
# men
# ment
# t
# x
# xp
# xpl
# xplo
# xplor
# xplore
# p
# pl
# plo
# plor
# plore
# l
# lo
# lor
# lore

# %% [markdown]
#  (c): Partial vocabulary tree

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end_of_word = False

class VocabularyTree:
    def __init__(self):
        self.root = TrieNode()

    def insert_word(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end_of_word = True

    def display_tree(self, node=None, prefix=''):
        if node is None:
            node = self.root
        for char, child in node.children.items():
            print(prefix + char)
            self.display_tree(child, prefix + char)

# Example usage
vocab_tree = VocabularyTree()
vocab_tree.insert_word("ocean")
vocab_tree.insert_word("environment")
vocab_tree.insert_word("explore")

print("\nPartial Vocabulary Tree:")
vocab_tree.display_tree()
# Out:
# Partial Vocabulary Tree:
# o
# oc
# oce
# ocea
# ocean
# e
# en
# env
# envi
# envir
# enviro
# environ
# environm
# environme
# environmen
# environment
# ex
# exp
# expl
# explo
# explor
# explore

# %% [markdown]
# ### Posting list

# %%
from collections import defaultdict
import re

# Define the document collection
documents = {
    "D1": "The universe is vast and mysterious, filled with countless stars and galaxies.",
    "D2": "Each star may host its own planets, some of which could harbor life.",
    "D3": "Scientists explore these possibilities through advanced telescopes and technology.",
    "D4": "Yet, many questions about our universe remain unanswered, driving curiosity and research.",
    "D5": "The quest for knowledge continues, pushing the boundaries of human understanding."
}

# We defined a small set of common stop words to filter out, based on the provided documents.
stop_words = {"the", "is", "and", "its", "of", "for", "with", "a", "may"}

# Create an empty inverted index (defaultdict to handle missing keys)
inverted_index = defaultdict(list)

# Tokenize and index each document
for doc_id, text in documents.items():
    # Tokenize text by splitting on non-alphanumeric characters, convert to lowercase
    words = re.findall(r'\w+', text.lower())
    # Filter out stop words and add words to the index
    for word in words:
        if word not in stop_words:
            # Append the document ID to the term's posting list if it's not already present
            if doc_id not in inverted_index[word]:
                inverted_index[word].append(doc_id)

# Display the inverted index
print("Inverted Index with Posting Lists:")
for term, posting_list in inverted_index.items():
    print(f"{term}: {posting_list}")
# Out:
# Inverted Index with Posting Lists:
# universe: ['D1', 'D4']
# vast: ['D1']
# mysterious: ['D1']
# filled: ['D1']
# countless: ['D1']
# stars: ['D1']
# galaxies: ['D1']
# each: ['D2']
# star: ['D2']
# host: ['D2']
# own: ['D2']
# planets: ['D2']
# some: ['D2']
# which: ['D2']
# could: ['D2']
# harbor: ['D2']
# life: ['D2']
# scientists: ['D3']
# explore: ['D3']
# these: ['D3']
# possibilities: ['D3']
# through: ['D3']
# advanced: ['D3']
# telescopes: ['D3']
# technology: ['D3']
# yet: ['D4']
# many: ['D4']
# questions: ['D4']
# about: ['D4']
# our: ['D4']
# remain: ['D4']
# unanswered: ['D4']
# driving: ['D4']
# curiosity: ['D4']
# research: ['D4']
# quest: ['D5']
# knowledge: ['D5']
# continues: ['D5']
# pushing: ['D5']
# boundaries: ['D5']
# human: ['D5']
# understanding: ['D5']

# %% [markdown]
# ## Task 2:
# task 2: (b) and (c)

# %%
import os
import re
from collections import defaultdict

# Task b: Implementation of a simple text indexer. 
class SimpleTextIndexer:
    def __init__(self):
        # Load stop words from a file
        with open('common-english-words.txt', 'r') as file:
            # Assuming stop words are comma-separated in the file
            stopwords = set(file.read().strip().split(","))
        
        # Create an inverted index: {word: [doc_ids]}
        self.inverted_index = defaultdict(set)
        self.stop_words = stopwords  # Use the loaded stop words
    
    def index_document(self, doc_id, text):
        # Tokenize text
        words = re.findall(r'\w+', text.lower())  # Lowercase to ensure case-insensitive search
        for word in words:
            # Ignore stop words
            if word not in self.stop_words:
                self.inverted_index[word].add(doc_id)
    
    def search(self, query):
        # Split the query and find documents containing each word
        query_words = query.lower().split()
        results = [self.inverted_index[word] for word in query_words if word in self.inverted_index]
        
        # Return documents containing all query words (intersection)
        if results:
            return set.intersection(*results)
        return set()

# Task c: Indexing documents provided in assignment.
# Function to index documents from a list
def index_documents_from_list(file_list, indexer, directory):
    # Go through each file in the provided list and index it
    for file_name in file_list:
        file_path = os.path.join(directory, file_name)
        if os.path.isfile(file_path):  # Check if the file exists
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    text = file.read()
                    indexer.index_document(file_name, text)
                    print(f"Indexed {file_name} successfully.")
            except Exception as e:
                print(f"An error occurred while reading {file_name}: {e}")
        else:
            print(f"File {file_name} not found at path: {file_path}")

# Define the path to your DataAssignment4 directory
data_directory = os.path.join(os.getcwd(), "DataAssignment4")
textFiles = ["Text1.txt", "Text2.txt", "Text3.txt", "Text4.txt", "Text5.txt", "Text6.txt"]

# Main execution for indexing documents
indexer = SimpleTextIndexer()
index_documents_from_list(textFiles, indexer, data_directory)

# Optionally, print the inverted index for verification
print("\nInverted Index:")
for word, doc_ids in indexer.inverted_index.items():
    print(f"{word}: {doc_ids}")
# Out:
# Indexed Text1.txt successfully.
# Indexed Text2.txt successfully.
# Indexed Text3.txt successfully.
# Indexed Text4.txt successfully.
# Indexed Text5.txt successfully.
# Indexed Text6.txt successfully.
#
# Inverted Index:
# wonderful: {'Text1.txt'}
# serenity: {'Text1.txt'}
# taken: {'Text1.txt'}
# possession: {'Text1.txt'}
# entire: {'Text1.txt'}
# soul: {'Text1.txt'}
# sweet: {'Text1.txt'}
# mornings: {'Text1.txt'}
# spring: {'Text1.txt'}
# enjoy: {'Text6.txt', 'Text1.txt'}
# whole: {'Text2.txt', 'Text1.txt'}
# heart: {'Text1.txt'}
# alone: {'Text1.txt'}
# feel: {'Text2.txt', 'Text1.txt'}
# charm: {'Text1.txt'}
# existence: {'Text5.txt', 'Text1.txt'}
# spot: {'Text2.txt', 'Text1.txt'}
# created: {'Text1.txt'}
# bliss: {'Text1.txt'}
# souls: {'Text1.txt'}
# mine: {'Text5.txt', 'Text1.txt'}
# happy: {'Text1.txt'}
# friend: {'Text5.txt', 'Text1.txt'}
# absorbed: {'Text1.txt'}
# exquisite: {'Text1.txt', 'Text3.txt'}
# sense: {'Text1.txt'}
# mere: {'Text1.txt'}
# tranquil: {'Text1.txt'}
# neglect: {'Text1.txt'}
# talents: {'Text1.txt'}
# incapable: {'Text1.txt'}
# drawing: {'Text1.txt'}
# single: {'Text1.txt'}
# stroke: {'Text1.txt'}
# present: {'Text2.txt', 'Text1.txt'}
# moment: {'Text6.txt', 'Text2.txt', 'Text1.txt'}
# never: {'Text2.txt', 'Text1.txt'}
# greater: {'Text6.txt', 'Text1.txt'}
# artist: {'Text1.txt'}
# now: {'Text2.txt', 'Text1.txt', 'Text3.txt'}
# lovely: {'Text1.txt'}
# valley: {'Text1.txt'}
# teems: {'Text1.txt'}
# vapour: {'Text1.txt'}
# around: {'Text1.txt', 'Text4.txt'}
# meridian: {'Text1.txt'}
# sun: {'Text1.txt'}
# strikes: {'Text1.txt'}
# upper: {'Text1.txt'}
# surface: {'Text1.txt'}
# impenetrable: {'Text1.txt'}
# foliage: {'Text1.txt'}
# trees: {'Text1.txt'}
# few: {'Text4.txt', 'Text1.txt', 'Text3.txt'}
# stray: {'Text1.txt'}
# gleams: {'Text1.txt'}
# steal: {'Text1.txt'}
# inner: {'Text1.txt'}
# sanctuary: {'Text1.txt'}
# throw: {'Text1.txt'}
# myself: {'Text1.txt'}
# down: {'Text2.txt', 'Text1.txt'}
# tall: {'Text1.txt'}
# grass: {'Text1.txt'}
# trickling: {'Text1.txt'}
# stream: {'Text1.txt'}
# lie: {'Text1.txt'}
# close: {'Text2.txt', 'Text1.txt'}
# earth: {'Text1.txt'}
# thousand: {'Text1.txt', 'Text4.txt'}
# unknown: {'Text1.txt'}
# plants: {'Text1.txt'}
# noticed: {'Text1.txt'}
# hear: {'Text1.txt'}
# buzz: {'Text1.txt'}
# little: {'Text2.txt', 'Text1.txt', 'Text4.txt'}
# world: {'Text1.txt', 'Text4.txt'}
# stalks: {'Text1.txt'}
# grow: {'Text1.txt'}
# familiar: {'Text2.txt', 'Text1.txt'}
# countless: {'Text1.txt'}
# indescribable: {'Text1.txt'}
# forms: {'Text1.txt'}
# insects: {'Text1.txt'}
# flies: {'Text1.txt'}
# presence: {'Text1.txt'}
# almighty: {'Text1.txt'}
# formed: {'Text1.txt'}
# image: {'Text1.txt'}
# breath: {'Text1.txt'}
# universal: {'Text1.txt'}
# love: {'Text1.txt'}
# bears: {'Text1.txt'}
# sustains: {'Text1.txt'}
# floats: {'Text1.txt'}
# eternity: {'Text1.txt'}
# darkness: {'Text1.txt'}
# overspreads: {'Text1.txt'}
# eyes: {'Text2.txt', 'Text1.txt'}
# heaven: {'Text2.txt', 'Text1.txt'}
# seem: {'Text5.txt', 'Text1.txt'}
# dwell: {'Text1.txt'}
# absorb: {'Text1.txt'}
# power: {'Text6.txt', 'Text1.txt'}
# form: {'Text1.txt'}
# beloved: {'Text1.txt'}
# mistress: {'Text1.txt'}
# think: {'Text2.txt', 'Text1.txt'}
# longing: {'Text1.txt'}
# oh: {'Text2.txt', 'Text1.txt'}
# describe: {'Text1.txt'}
# conceptions: {'Text1.txt'}
# impress: {'Text1.txt'}
# upon: {'Text1.txt'}
# paper: {'Text1.txt'}
# living: {'Text1.txt'}
# full: {'Text1.txt'}
# warm: {'Text1.txt'}
# within: {'Text1.txt'}
# mirror: {'Text1.txt'}
# infinite: {'Text1.txt'}
# god: {'Text2.txt', 'Text1.txt'}
# o: {'Text2.txt', 'Text1.txt'}
# much: {'Text2.txt', 'Text1.txt'}
# strength: {'Text1.txt'}
# sink: {'Text1.txt'}
# under: {'Text1.txt'}
# weight: {'Text1.txt'}
# splendour: {'Text1.txt'}
# visions: {'Text1.txt'}
# one: {'Text5.txt', 'Text2.txt', 'Text6.txt', 'Text4.txt'}
# morning: {'Text2.txt'}
# gregor: {'Text2.txt'}
# samsa: {'Text2.txt'}
# woke: {'Text2.txt'}
# troubled: {'Text2.txt'}
# dreams: {'Text2.txt'}
# found: {'Text2.txt'}
# himself: {'Text2.txt'}
# transformed: {'Text2.txt'}
# bed: {'Text2.txt', 'Text3.txt'}
# horrible: {'Text2.txt'}
# vermin: {'Text2.txt'}
# lay: {'Text2.txt'}
# armour: {'Text2.txt'}
# back: {'Text2.txt', 'Text4.txt'}
# lifted: {'Text2.txt'}
# head: {'Text2.txt'}
# see: {'Text2.txt'}
# brown: {'Text2.txt', 'Text3.txt'}
# belly: {'Text2.txt'}
# slightly: {'Text2.txt'}
# domed: {'Text2.txt'}
# divided: {'Text2.txt'}
# arches: {'Text2.txt'}
# stiff: {'Text2.txt'}
# sections: {'Text2.txt'}
# bedding: {'Text2.txt'}
# hardly: {'Text2.txt'}
# cover: {'Text2.txt'}
# seemed: {'Text2.txt'}
# ready: {'Text2.txt'}
# slide: {'Text2.txt'}
# many: {'Text2.txt', 'Text3.txt'}
# legs: {'Text2.txt'}
# pitifully: {'Text2.txt'}
# thin: {'Text2.txt'}
# compared: {'Text2.txt'}
# size: {'Text2.txt'}
# rest: {'Text2.txt'}
# waved: {'Text2.txt'}
# helplessly: {'Text2.txt'}
# looked: {'Text2.txt'}
# s: {'Text2.txt', 'Text3.txt'}
# happened: {'Text2.txt'}
# thought: {'Text2.txt'}
# wasn: {'Text2.txt'}
# t: {'Text2.txt', 'Text4.txt'}
# dream: {'Text2.txt'}
# room: {'Text2.txt'}
# proper: {'Text2.txt'}
# human: {'Text2.txt', 'Text6.txt'}
# although: {'Text2.txt'}
# small: {'Text2.txt', 'Text4.txt'}
# peacefully: {'Text2.txt'}
# between: {'Text2.txt'}
# four: {'Text2.txt'}
# walls: {'Text2.txt'}
# collection: {'Text2.txt'}
# textile: {'Text2.txt'}
# samples: {'Text2.txt'}
# spread: {'Text2.txt'}
# out: {'Text2.txt'}
# table: {'Text2.txt'}
# travelling: {'Text2.txt'}
# salesman: {'Text2.txt'}
# above: {'Text2.txt'}
# hung: {'Text2.txt'}
# picture: {'Text2.txt'}
# recently: {'Text2.txt'}
# cut: {'Text2.txt'}
# illustrated: {'Text2.txt'}
# magazine: {'Text2.txt'}
# housed: {'Text2.txt'}
# nice: {'Text2.txt'}
# gilded: {'Text2.txt'}
# frame: {'Text2.txt'}
# showed: {'Text2.txt'}
# lady: {'Text2.txt'}
# fitted: {'Text2.txt'}
# fur: {'Text2.txt'}
# hat: {'Text2.txt'}
# boa: {'Text2.txt'}
# sat: {'Text2.txt'}
# upright: {'Text2.txt'}
# raising: {'Text2.txt'}
# heavy: {'Text2.txt'}
# muff: {'Text2.txt'}
# covered: {'Text2.txt'}
# lower: {'Text2.txt'}
# arm: {'Text2.txt'}
# towards: {'Text2.txt'}
# viewer: {'Text2.txt'}
# turned: {'Text2.txt'}
# look: {'Text2.txt'}
# window: {'Text2.txt'}
# dull: {'Text2.txt'}
# weather: {'Text2.txt'}
# drops: {'Text2.txt'}
# rain: {'Text2.txt'}
# heard: {'Text2.txt'}
# hitting: {'Text2.txt'}
# pane: {'Text2.txt'}
# made: {'Text2.txt', 'Text4.txt'}
# quite: {'Text2.txt'}
# sad: {'Text2.txt'}
# sleep: {'Text2.txt'}
# bit: {'Text2.txt'}
# longer: {'Text2.txt'}
# forget: {'Text2.txt'}
# nonsense: {'Text2.txt'}
# something: {'Text2.txt'}
# unable: {'Text2.txt'}
# used: {'Text2.txt'}
# sleeping: {'Text2.txt'}
# right: {'Text2.txt', 'Text6.txt', 'Text4.txt'}
# state: {'Text2.txt'}
# couldn: {'Text2.txt'}
# position: {'Text2.txt'}
# hard: {'Text2.txt'}
# threw: {'Text2.txt'}
# onto: {'Text2.txt'}
# always: {'Text2.txt', 'Text6.txt'}
# rolled: {'Text2.txt'}
# tried: {'Text2.txt'}
# hundred: {'Text2.txt'}
# times: {'Text2.txt', 'Text4.txt'}
# shut: {'Text2.txt'}
# wouldn: {'Text2.txt'}
# floundering: {'Text2.txt'}
# stopped: {'Text2.txt'}
# began: {'Text2.txt'}
# mild: {'Text2.txt'}
# pain: {'Text2.txt', 'Text6.txt'}
# felt: {'Text2.txt'}
# before: {'Text2.txt', 'Text3.txt'}
# strenuous: {'Text2.txt'}
# career: {'Text2.txt'}
# ve: {'Text2.txt'}
# chosen: {'Text2.txt'}
# day: {'Text2.txt', 'Text4.txt'}
# doing: {'Text2.txt'}
# business: {'Text2.txt', 'Text6.txt'}
# takes: {'Text2.txt'}
# more: {'Text5.txt', 'Text2.txt'}
# effort: {'Text2.txt'}
# home: {'Text2.txt'}
# top: {'Text2.txt'}
# curse: {'Text2.txt'}
# worries: {'Text2.txt'}
# making: {'Text2.txt'}
# train: {'Text2.txt'}
# connections: {'Text2.txt'}
# bad: {'Text2.txt', 'Text3.txt', 'Text4.txt'}
# irregular: {'Text2.txt'}
# food: {'Text2.txt'}
# contact: {'Text2.txt'}
# different: {'Text2.txt'}
# people: {'Text2.txt'}
# time: {'Text2.txt'}
# know: {'Text2.txt', 'Text6.txt'}
# anyone: {'Text2.txt', 'Text6.txt'}
# become: {'Text2.txt'}
# friendly: {'Text2.txt'}
# go: {'Text2.txt'}
# hell: {'Text2.txt'}
# slight: {'Text2.txt'}
# itch: {'Text2.txt'}
# up: {'Text2.txt', 'Text3.txt'}
# pushed: {'Text2.txt'}
# slowly: {'Text2.txt'}
# headboard: {'Text2.txt'}
# lift: {'Text2.txt'}
# better: {'Text2.txt'}
# saw: {'Text2.txt'}
# lots: {'Text2.txt'}
# white: {'Text2.txt'}
# spots: {'Text2.txt'}
# didn: {'Text2.txt', 'Text4.txt'}
# make: {'Text2.txt'}
# place: {'Text2.txt', 'Text4.txt'}
# drew: {'Text2.txt'}
# quickly: {'Text2.txt', 'Text3.txt'}
# soon: {'Text2.txt'}
# touched: {'Text2.txt'}
# overcome: {'Text2.txt'}
# cold: {'Text2.txt'}
# shudder: {'Text2.txt'}
# slid: {'Text2.txt'}
# former: {'Text2.txt'}
# getting: {'Text2.txt'}
# early: {'Text2.txt'}
# makes: {'Text2.txt'}
# stupid: {'Text2.txt'}
# enough: {'Text2.txt'}
# salesmen: {'Text2.txt'}
# live: {'Text2.txt', 'Text4.txt'}
# life: {'Text2.txt', 'Text4.txt'}
# luxury: {'Text2.txt'}
# instance: {'Text2.txt'}
# whenever: {'Text2.txt'}
# guest: {'Text2.txt'}
# house: {'Text2.txt'}
# during: {'Text2.txt'}
# copy: {'Text2.txt', 'Text4.txt'}
# contract: {'Text2.txt'}
# gentlemen: {'Text2.txt'}
# still: {'Text2.txt', 'Text4.txt'}
# sitting: {'Text2.txt'}
# eating: {'Text2.txt'}
# breakfasts: {'Text2.txt'}
# ought: {'Text2.txt'}
# try: {'Text2.txt'}
# boss: {'Text2.txt'}
# d: {'Text2.txt'}
# kicked: {'Text2.txt'}
# knows: {'Text2.txt'}
# maybe: {'Text2.txt'}
# best: {'Text2.txt', 'Text6.txt'}
# thing: {'Text2.txt'}
# parents: {'Text2.txt'}
# given: {'Text2.txt'}
# notice: {'Text2.txt'}
# long: {'Text2.txt', 'Text4.txt'}
# ago: {'Text2.txt'}
# gone: {'Text2.txt'}
# told: {'Text5.txt', 'Text2.txt'}
# tell: {'Text2.txt'}
# everything: {'Text2.txt', 'Text4.txt'}
# fall: {'Text2.txt'}
# desk: {'Text2.txt'}
# funny: {'Text2.txt'}
# sort: {'Text2.txt'}
# talking: {'Text2.txt'}
# subordinates: {'Text2.txt'}
# especially: {'Text2.txt'}
# hearing: {'Text2.txt'}
# well: {'Text2.txt'}
# hope: {'Text2.txt'}
# once: {'Text2.txt'}
# money: {'Text2.txt'}
# together: {'Text2.txt'}
# pay: {'Text5.txt', 'Text2.txt'}
# debt: {'Text2.txt'}
# another: {'Text2.txt'}
# five: {'Text2.txt', 'Text3.txt'}
# six: {'Text2.txt', 'Text3.txt'}
# years: {'Text2.txt'}
# suppose: {'Text2.txt'}
# definitely: {'Text2.txt'}
# ll: {'Text2.txt'}
# big: {'Text2.txt', 'Text3.txt', 'Text4.txt'}
# change: {'Text2.txt'}
# first: {'Text2.txt', 'Text4.txt'}
# though: {'Text2.txt'}
# leaves: {'Text2.txt'}
# over: {'Text2.txt', 'Text3.txt', 'Text4.txt'}
# alarm: {'Text2.txt'}
# clock: {'Text2.txt'}
# ticking: {'Text2.txt'}
# chest: {'Text2.txt'}
# drawers: {'Text2.txt'}
# half: {'Text2.txt'}
# past: {'Text2.txt'}
# hands: {'Text2.txt'}
# quietly: {'Text2.txt', 'Text3.txt'}
# moving: {'Text2.txt'}
# forwards: {'Text2.txt'}
# even: {'Text2.txt', 'Text4.txt'}
# later: {'Text2.txt'}
# quarter: {'Text2.txt'}
# seven: {'Text2.txt', 'Text4.txt'}
# rung: {'Text2.txt'}
# set: {'Text2.txt'}
# certainly: {'Text2.txt'}
# yes: {'Text2.txt'}
# possible: {'Text2.txt'}
# through: {'Text2.txt', 'Text6.txt'}
# furniture: {'Text2.txt'}
# rattling: {'Text2.txt'}
# noise: {'Text2.txt'}
# true: {'Text2.txt'}
# slept: {'Text2.txt'}
# probably: {'Text2.txt'}
# deeply: {'Text2.txt'}
# next: {'Text2.txt'}
# went: {'Text2.txt'}
# catch: {'Text2.txt'}
# rush: {'Text2.txt'}
# mad: {'Text2.txt'}
# packed: {'Text2.txt', 'Text4.txt'}
# particularly: {'Text2.txt'}
# fresh: {'Text2.txt'}
# lively: {'Text2.txt'}
# avoid: {'Text2.txt', 'Text6.txt'}
# anger: {'Text2.txt'}
# office: {'Text2.txt'}
# assistant: {'Text2.txt'}
# put: {'Text2.txt', 'Text4.txt'}
# report: {'Text2.txt'}
# being: {'Text2.txt', 'Text6.txt'}
# man: {'Text2.txt', 'Text6.txt'}
# spineless: {'Text2.txt'}
# understanding: {'Text2.txt'}
# reported: {'Text2.txt'}
# sick: {'Text2.txt'}
# extremely: {'Text2.txt', 'Text6.txt'}
# strained: {'Text2.txt'}
# suspicious: {'Text2.txt'}
# fifteen: {'Text2.txt'}
# service: {'Text2.txt'}
# ill: {'Text2.txt'}
# come: {'Text2.txt'}
# round: {'Text2.txt'}
# doctor: {'Text2.txt'}
# medical: {'Text2.txt'}
# insurance: {'Text2.txt'}
# company: {'Text2.txt'}
# accuse: {'Text2.txt'}
# having: {'Text2.txt'}
# lazy: {'Text2.txt', 'Text3.txt'}
# son: {'Text2.txt'}
# accept: {'Text2.txt'}
# recommendation: {'Text2.txt'}
# claim: {'Text2.txt'}
# believed: {'Text2.txt'}
# workshy: {'Text2.txt'}
# entirely: {'Text2.txt'}
# wrong: {'Text2.txt'}
# case: {'Text2.txt'}
# quick: {'Text3.txt'}
# fox: {'Text3.txt'}
# jumps: {'Text3.txt'}
# dog: {'Text3.txt'}
# djs: {'Text3.txt'}
# flock: {'Text3.txt'}
# mtv: {'Text3.txt'}
# ax: {'Text3.txt'}
# quiz: {'Text3.txt'}
# prog: {'Text3.txt'}
# junk: {'Text3.txt'}
# graced: {'Text3.txt'}
# whelps: {'Text3.txt'}
# bawds: {'Text3.txt'}
# jog: {'Text3.txt'}
# flick: {'Text3.txt'}
# quartz: {'Text3.txt'}
# vex: {'Text3.txt'}
# nymphs: {'Text3.txt'}
# waltz: {'Text3.txt'}
# nymph: {'Text3.txt'}
# jigs: {'Text3.txt'}
# grab: {'Text3.txt'}
# jived: {'Text3.txt'}
# brick: {'Text3.txt'}
# whangs: {'Text3.txt'}
# jumpy: {'Text3.txt'}
# veldt: {'Text3.txt'}
# bright: {'Text3.txt'}
# vixens: {'Text3.txt'}
# jump: {'Text3.txt'}
# dozy: {'Text3.txt'}
# fowl: {'Text3.txt'}
# quack: {'Text3.txt'}
# wafting: {'Text3.txt'}
# zephyrs: {'Text3.txt'}
# bold: {'Text3.txt'}
# jim: {'Text3.txt'}
# blow: {'Text3.txt'}
# vexing: {'Text3.txt'}
# daft: {'Text3.txt'}
# sex: {'Text3.txt'}
# charged: {'Text3.txt'}
# fop: {'Text3.txt'}
# blew: {'Text3.txt'}
# tv: {'Text3.txt'}
# jumping: {'Text3.txt'}
# zebras: {'Text3.txt'}
# two: {'Text3.txt'}
# driven: {'Text3.txt'}
# jocks: {'Text3.txt'}
# help: {'Text3.txt'}
# fax: {'Text3.txt'}
# baz: {'Text3.txt'}
# woven: {'Text3.txt'}
# flax: {'Text3.txt'}
# jodhpurs: {'Text3.txt'}
# jack: {'Text3.txt'}
# brave: {'Text3.txt'}
# ghost: {'Text3.txt'}
# pled: {'Text3.txt'}
# quacking: {'Text3.txt'}
# jolt: {'Text3.txt'}
# wax: {'Text3.txt'}
# flummoxed: {'Text3.txt'}
# job: {'Text3.txt'}
# kvetching: {'Text3.txt'}
# w: {'Text3.txt'}
# zaps: {'Text3.txt'}
# iraq: {'Text3.txt'}
# cozy: {'Text3.txt'}
# sphinx: {'Text3.txt'}
# waves: {'Text3.txt'}
# quart: {'Text3.txt'}
# jug: {'Text3.txt'}
# milk: {'Text3.txt'}
# very: {'Text3.txt'}
# jinx: {'Text3.txt'}
# zippy: {'Text3.txt'}
# fowls: {'Text3.txt'}
# quips: {'Text3.txt'}
# galvanized: {'Text3.txt'}
# mock: {'Text3.txt'}
# jury: {'Text3.txt'}
# box: {'Text3.txt'}
# dogs: {'Text3.txt'}
# jay: {'Text3.txt'}
# pig: {'Text3.txt'}
# zebra: {'Text3.txt'}
# wolves: {'Text3.txt'}
# blowzy: {'Text3.txt'}
# red: {'Text3.txt'}
# fight: {'Text3.txt'}
# joaquin: {'Text3.txt'}
# phoenix: {'Text3.txt'}
# gazed: {'Text3.txt'}
# luck: {'Text3.txt'}
# wizard: {'Text3.txt'}
# chumps: {'Text3.txt'}
# fog: {'Text3.txt'}
# watch: {'Text3.txt'}
# jeopardy: {'Text3.txt'}
# alex: {'Text3.txt'}
# trebek: {'Text3.txt'}
# fun: {'Text3.txt'}
# game: {'Text3.txt'}
# silk: {'Text3.txt'}
# pyjamas: {'Text3.txt'}
# exchanged: {'Text3.txt'}
# blue: {'Text3.txt'}
# brawny: {'Text3.txt'}
# gods: {'Text3.txt'}
# flocked: {'Text3.txt'}
# adjusting: {'Text3.txt'}
# quiver: {'Text3.txt'}
# bow: {'Text3.txt'}
# zompyc: {'Text3.txt'}
# 1: {'Text3.txt'}
# killed: {'Text3.txt'}
# faxed: {'Text3.txt'}
# joke: {'Text3.txt'}
# won: {'Text3.txt'}
# pager: {'Text3.txt'}
# cable: {'Text3.txt'}
# show: {'Text3.txt'}
# amazingly: {'Text3.txt'}
# discotheques: {'Text3.txt'}
# provide: {'Text3.txt'}
# jukeboxes: {'Text3.txt'}
# girl: {'Text3.txt'}
# wove: {'Text3.txt'}
# dozen: {'Text3.txt'}
# plaid: {'Text3.txt'}
# jackets: {'Text3.txt'}
# quit: {'Text3.txt'}
# devils: {'Text3.txt'}
# japan: {'Text3.txt'}
# forgot: {'Text3.txt'}
# july: {'Text3.txt'}
# earthquakes: {'Text3.txt'}
# confound: {'Text3.txt'}
# zany: {'Text3.txt'}
# experimental: {'Text3.txt'}
# vow: {'Text3.txt'}
# foxy: {'Text3.txt'}
# parsons: {'Text3.txt'}
# cajole: {'Text3.txt'}
# lovably: {'Text3.txt'}
# dim: {'Text3.txt'}
# wiki: {'Text3.txt'}
# pick: {'Text3.txt'}
# twenty: {'Text3.txt'}
# letters: {'Text3.txt'}
# forcing: {'Text3.txt'}
# jumbled: {'Text3.txt'}
# crazy: {'Text3.txt'}
# fredericka: {'Text3.txt'}
# bought: {'Text3.txt'}
# opal: {'Text3.txt'}
# jewels: {'Text3.txt'}
# sixty: {'Text3.txt'}
# zippers: {'Text3.txt'}
# picked: {'Text3.txt'}
# jute: {'Text3.txt'}
# bag: {'Text3.txt'}
# movement: {'Text3.txt'}
# enemy: {'Text3.txt'}
# jeopardize: {'Text3.txt'}
# gunboats: {'Text3.txt'}
# questions: {'Text3.txt'}
# asked: {'Text3.txt'}
# experts: {'Text3.txt'}
# amazed: {'Text3.txt'}
# judge: {'Text3.txt'}
# moved: {'Text3.txt'}
# front: {'Text3.txt'}
# seized: {'Text3.txt'}
# ball: {'Text3.txt'}
# far: {'Text4.txt'}
# away: {'Text4.txt'}
# behind: {'Text4.txt'}
# word: {'Text4.txt'}
# mountains: {'Text4.txt'}
# countries: {'Text4.txt'}
# vokalia: {'Text4.txt'}
# consonantia: {'Text4.txt'}
# blind: {'Text4.txt'}
# texts: {'Text4.txt'}
# separated: {'Text4.txt'}
# bookmarksgrove: {'Text4.txt'}
# coast: {'Text4.txt'}
# semantics: {'Text4.txt'}
# large: {'Text4.txt'}
# language: {'Text5.txt', 'Text4.txt'}
# ocean: {'Text4.txt'}
# river: {'Text4.txt'}
# named: {'Text4.txt'}
# duden: {'Text4.txt'}
# flows: {'Text4.txt'}
# supplies: {'Text4.txt'}
# necessary: {'Text5.txt', 'Text4.txt'}
# regelialia: {'Text4.txt'}
# paradisematic: {'Text4.txt'}
# country: {'Text4.txt'}
# roasted: {'Text4.txt'}
# parts: {'Text4.txt'}
# sentences: {'Text4.txt'}
# fly: {'Text4.txt'}
# mouth: {'Text4.txt'}
# powerful: {'Text4.txt'}
# pointing: {'Text4.txt'}
# control: {'Text4.txt'}
# unorthographic: {'Text4.txt'}
# line: {'Text4.txt'}
# text: {'Text4.txt'}
# name: {'Text4.txt'}
# lorem: {'Text4.txt'}
# ipsum: {'Text4.txt'}
# decided: {'Text4.txt'}
# leave: {'Text4.txt'}
# grammar: {'Text5.txt', 'Text4.txt'}
# oxmox: {'Text4.txt'}
# advised: {'Text4.txt'}
# thousands: {'Text4.txt'}
# commas: {'Text4.txt'}
# wild: {'Text4.txt'}
# question: {'Text4.txt'}
# marks: {'Text4.txt'}
# devious: {'Text4.txt'}
# semikoli: {'Text4.txt'}
# listen: {'Text4.txt'}
# versalia: {'Text4.txt'}
# initial: {'Text4.txt'}
# belt: {'Text4.txt'}
# herself: {'Text4.txt'}
# way: {'Text4.txt'}
# reached: {'Text4.txt'}
# hills: {'Text4.txt'}
# italic: {'Text4.txt'}
# last: {'Text4.txt'}
# view: {'Text4.txt'}
# skyline: {'Text4.txt'}
# hometown: {'Text4.txt'}
# headline: {'Text4.txt'}
# alphabet: {'Text4.txt'}
# village: {'Text4.txt'}
# subline: {'Text4.txt'}
# road: {'Text4.txt'}
# lane: {'Text4.txt'}
# pityful: {'Text4.txt'}
# rethoric: {'Text4.txt'}
# ran: {'Text4.txt'}
# cheek: {'Text4.txt'}
# continued: {'Text4.txt'}
# met: {'Text4.txt'}
# warned: {'Text4.txt'}
# came: {'Text4.txt'}
# rewritten: {'Text4.txt'}
# left: {'Text4.txt'}
# origin: {'Text4.txt'}
# turn: {'Text4.txt'}
# return: {'Text4.txt'}
# safe: {'Text4.txt'}
# nothing: {'Text6.txt', 'Text4.txt'}
# convince: {'Text4.txt'}
# take: {'Text6.txt', 'Text4.txt'}
# until: {'Text4.txt'}
# insidious: {'Text4.txt'}
# writers: {'Text4.txt'}
# ambushed: {'Text4.txt'}
# drunk: {'Text4.txt'}
# longe: {'Text4.txt'}
# parole: {'Text4.txt'}
# dragged: {'Text4.txt'}
# agency: {'Text4.txt'}
# abused: {'Text4.txt'}
# projects: {'Text4.txt'}
# again: {'Text6.txt', 'Text4.txt'}
# hasn: {'Text4.txt'}
# using: {'Text4.txt'}
# european: {'Text5.txt'}
# languages: {'Text5.txt'}
# members: {'Text5.txt'}
# same: {'Text5.txt', 'Text6.txt'}
# family: {'Text5.txt'}
# separate: {'Text5.txt'}
# myth: {'Text5.txt'}
# science: {'Text5.txt'}
# music: {'Text5.txt'}
# sport: {'Text5.txt'}
# etc: {'Text5.txt'}
# europe: {'Text5.txt'}
# uses: {'Text5.txt'}
# vocabulary: {'Text5.txt'}
# differ: {'Text5.txt'}
# pronunciation: {'Text5.txt'}
# common: {'Text5.txt'}
# words: {'Text5.txt'}
# everyone: {'Text5.txt'}
# realizes: {'Text5.txt'}
# new: {'Text5.txt'}
# desirable: {'Text5.txt'}
# refuse: {'Text5.txt'}
# expensive: {'Text5.txt'}
# translators: {'Text5.txt'}
# achieve: {'Text5.txt'}
# uniform: {'Text5.txt'}
# several: {'Text5.txt'}
# coalesce: {'Text5.txt'}
# resulting: {'Text5.txt'}
# simple: {'Text5.txt', 'Text6.txt'}
# regular: {'Text5.txt'}
# individual: {'Text5.txt'}
# existing: {'Text5.txt'}
# occidental: {'Text5.txt'}
# fact: {'Text5.txt'}
# english: {'Text5.txt'}
# person: {'Text5.txt'}
# simplified: {'Text5.txt'}
# skeptical: {'Text5.txt'}
# cambridge: {'Text5.txt'}
# explain: {'Text6.txt'}
# mistaken: {'Text6.txt'}
# idea: {'Text6.txt'}
# denouncing: {'Text6.txt'}
# pleasure: {'Text6.txt'}
# praising: {'Text6.txt'}
# born: {'Text6.txt'}
# give: {'Text6.txt'}
# complete: {'Text6.txt'}
# account: {'Text6.txt'}
# system: {'Text6.txt'}
# expound: {'Text6.txt'}
# actual: {'Text6.txt'}
# teachings: {'Text6.txt'}
# great: {'Text6.txt'}
# explorer: {'Text6.txt'}
# truth: {'Text6.txt'}
# master: {'Text6.txt'}
# builder: {'Text6.txt'}
# happiness: {'Text6.txt'}
# rejects: {'Text6.txt'}
# dislikes: {'Text6.txt'}
# avoids: {'Text6.txt'}
# itself: {'Text6.txt'}
# those: {'Text6.txt'}
# pursue: {'Text6.txt'}
# rationally: {'Text6.txt'}
# encounter: {'Text6.txt'}
# consequences: {'Text6.txt'}
# painful: {'Text6.txt'}
# loves: {'Text6.txt'}
# pursues: {'Text6.txt'}
# desires: {'Text6.txt'}
# obtain: {'Text6.txt'}
# occasionally: {'Text6.txt'}
# circumstances: {'Text6.txt'}
# occur: {'Text6.txt'}
# toil: {'Text6.txt'}
# procure: {'Text6.txt'}
# trivial: {'Text6.txt'}
# example: {'Text6.txt'}
# undertakes: {'Text6.txt'}
# laborious: {'Text6.txt'}
# physical: {'Text6.txt'}
# exercise: {'Text6.txt'}
# except: {'Text6.txt'}
# advantage: {'Text6.txt'}
# find: {'Text6.txt'}
# fault: {'Text6.txt'}
# chooses: {'Text6.txt'}
# annoying: {'Text6.txt'}
# produces: {'Text6.txt'}
# resultant: {'Text6.txt'}
# hand: {'Text6.txt'}
# denounce: {'Text6.txt'}
# righteous: {'Text6.txt'}
# indignation: {'Text6.txt'}
# dislike: {'Text6.txt'}
# men: {'Text6.txt'}
# beguiled: {'Text6.txt'}
# demoralized: {'Text6.txt'}
# charms: {'Text6.txt'}
# blinded: {'Text6.txt'}
# desire: {'Text6.txt'}
# foresee: {'Text6.txt'}
# trouble: {'Text6.txt'}
# bound: {'Text6.txt'}
# ensue: {'Text6.txt'}
# equal: {'Text6.txt'}
# blame: {'Text6.txt'}
# belongs: {'Text6.txt'}
# fail: {'Text6.txt'}
# duty: {'Text6.txt'}
# weakness: {'Text6.txt'}
# saying: {'Text6.txt'}
# shrinking: {'Text6.txt'}
# cases: {'Text6.txt'}
# perfectly: {'Text6.txt'}
# easy: {'Text6.txt'}
# distinguish: {'Text6.txt'}
# free: {'Text6.txt'}
# hour: {'Text6.txt'}
# choice: {'Text6.txt'}
# untrammelled: {'Text6.txt'}
# prevents: {'Text6.txt'}
# welcomed: {'Text6.txt'}
# avoided: {'Text6.txt'}
# certain: {'Text6.txt'}
# owing: {'Text6.txt'}
# claims: {'Text6.txt'}
# obligations: {'Text6.txt'}
# frequently: {'Text6.txt'}
# pleasures: {'Text6.txt'}
# repudiated: {'Text6.txt'}
# annoyances: {'Text6.txt'}
# accepted: {'Text6.txt'}
# wise: {'Text6.txt'}
# therefore: {'Text6.txt'}
# holds: {'Text6.txt'}
# matters: {'Text6.txt'}
# principle: {'Text6.txt'}
# selection: {'Text6.txt'}
# secure: {'Text6.txt'}
# endures: {'Text6.txt'}
# pains: {'Text6.txt'}
# worse: {'Text6.txt'}
